# %%
# 동적 사이트 수집
from selenium import webdriver
# 크롬 드라이버 설치
from webdriver_manager.chrome import ChromeDriverManager
# 자동적 접근
from selenium.webdriver.chrome.service import Service 
# 크롭 드라이버 옵션 지정
from selenium.webdriver.chrome.options import Options
# find_element 함수 쉽게 쓰기 위함 
from selenium.webdriver.common.by import By 
from selenium.webdriver.common.keys import Keys
import time
from bs4 import BeautifulSoup
import pandas as pd
import numpy as np

# %%
l_dt = 1.5
s_dt = 0.5
count = 0

def check_add(word):
    w_L = []
    for w in word.split():
        if w not in w_L:
            w_L.append(w)
    return ' '.join(w_L)

csv_list = ['Sejong.csv']
result_L = []

url = 'https://map.naver.com/p?c=15.00,0,0,0,dh'
driver = webdriver.Chrome() 
driver.get(url)
time.sleep(l_dt)

search_btn = driver.find_element(By.CSS_SELECTOR, 'div.input_box > input.input_search')
search_btn.click()
time.sleep(s_dt)

for csv_i in range(len(csv_list)):
    
    df = pd.read_csv(f'C:/python/mini_project_1/{csv_list[csv_i]}')
    df.columns = ('0','업종','업소명','주요품목','가격','연락처','주소')
    df.drop('0',axis=1,inplace=True)
    
    df['수정주소'] =  df['주소'].apply(lambda x : check_add(x))
    df['검색어'] = df['수정주소'].apply(lambda x : x.split()[0]) + ' ' + df['수정주소'].apply(lambda x : x.split()[1]) + ' ' + df['업소명']
    
    for k_word in df['검색어'].values:
        
        count = count + 1
        
        if count == 500:
            print("인터넷새창열기")
            url = 'https://map.naver.com/p?c=15.00,0,0,0,dh'
            driver = webdriver.Chrome() 
            driver.get(url)
            time.sleep(l_dt)

            search_btn = driver.find_element(By.CSS_SELECTOR, 'div.input_box > input.input_search')
            search_btn.click()
            time.sleep(s_dt)
            count = 0

        search_btn.send_keys(k_word)
        search_btn.send_keys(Keys.ENTER)
        time.sleep(l_dt)
        
        try:
            driver.switch_to.frame('searchIframe')
            try:
                #print("선택1")
                item_btn = driver.find_element(By.CSS_SELECTOR,'#app-root > div > div > div > div:nth-child(2) > div:nth-child(1) > div:nth-child(2) > span')
                #집에서 됨 item_btn = driver.find_element(By.CSS_SELECTOR,'#app-root > div > div > divnth-child(1) > ul > li:nth-child(1) > div:nth-child(1) > div:nth-child(2) > a')
                #item_btn = driver.find_element(By.XPATH,'/html/body/div[3]/div/div[2]/div[1]/ul/li[1]/div[1]')
                item_btn.click()
            except:
                try:
                    #print("선택2")
                    item_btn = driver.find_element(By.XPATH,'//*[@id="_pcmap_list_scroll_container"]/ul/li/div[1]/a[1]')
                    item_btn.click()
                except:
                    try:
                        #print("선택3")
                        item_btn = driver.find_element(By.CSS_SELECTOR,'#_pcmap_list_scroll_container > ul > li:nth-child(1) > div.qbGlu > div.ouxiq > a:nth-child(1) > div > div')
                        item_btn.click()
                    except:
                        #print("선택4")
                        item_btn = driver.find_element(By.XPATH,'/html/body/div[3]/div/div[2]/div[1]/ul/li[1]/div[1]')
                        item_btn.click()
                        
            time.sleep(l_dt)
            
        except:
            pass
        
        try:
            #print("세부선택")
            driver.switch_to.default_content()    
            driver.switch_to.frame('entryIframe')
#           time.sleep(s_dt)
        except:
            pass

        try:
            #item = driver.find_element(By.XPATH,'//*[@id="app-root"]/div/div/div/div[2]/div[1]/div[2]')
            item = driver.find_element(By.XPATH,'//*[@id="app-root"]/div/div/div/div[2]/div[1]/div[2]/span[1]')
            result_L.append(item.text)
            print(csv_i, k_word)
            print(result_L[-1])
            print("-"*20)   
            
        except:
            result_L.append('별점없음')
            print(result_L[-1])
            print("-"*20)
        
        driver.switch_to.default_content()
#        time.sleep(s_dt)
        
        c_btn = driver.find_element(By.XPATH,'//*[@id="app-layout"]/div[1]/div/div[1]/div/div/button[2]')
        c_btn.click()
#        time.sleep(s_dt)
    
    df['별점'] = result_L
    df.to_csv(f'C:/python/mini_project_1/ver2_{csv_list[csv_i]}')
    result_L.clear()
# Out:
# 0 경상남도 밀양시 아줌마우동
# 방문자리뷰 12
# --------------------
# 0 경상남도 밀양시 굴림당
# 방문자리뷰 1,279
# --------------------
# 별점없음
# --------------------
# 0 경상남도 통영시 살롱드 해미
# 방문자리뷰 11
# --------------------
# 0 경상남도 통영시 성포횟집
# 별점
# 4.57
# --------------------
# 0 경상남도 통영시 만풍해물뚝배기
# 별점
# 4.6
# --------------------
# 0 경상남도 통영시 통영잔치국수
# 방문자리뷰 144
# --------------------
# 0 경상남도 창녕군 양동손칼국수
# 별점
# 4.65
# --------------------
# 0 경상남도 창녕군 장백산칼국수
# 별점
# 4.21
# --------------------
# 별점없음
# --------------------
# 0 경상남도 창녕군 덕대반점
# 방문자리뷰 23
# --------------------
# 0 경상남도 밀양시 솔로몬독서실
# 방문자리뷰 3
# --------------------
# 별점없음
# --------------------
# 별점없음
# --------------------
# 0 경상남도 밀양시 수아
# 방문자리뷰 2
# --------------------
# 0 경상남도 합천군 영호식당
# 별점
# 4.14
# --------------------
# 0 경상남도 거창군 한다라이
# 방문자리뷰 9
# --------------------
# 0 경상남도 양산시 아빠축산
# 별점
# 4.82
# --------------------
# 0 경상남도 양산시 흙내음반찬
# 방문자리뷰 4
# --------------------
# 0 경상남도 양산시 파니파니
# 방문자리뷰 12
# --------------------
# 0 경상남도 창원시 조크리닝
# 별점
# 4.31
# --------------------
# 0 경상남도 창원시 복가득뚱보갈비
# 별점
# 4.78
# --------------------
# 0 경상남도 진주시 365건강드림운동센터
# 방문자리뷰 4
# --------------------
# 0 경상남도 진주시 국수타임
# 별점
# 4.37
# --------------------
# 0 경상남도 남해군 사랑채
# 별점
# 4.15
# --------------------
# 0 경상남도 진주시 커피빅스
# 별점
# 4.19
# --------------------
# 0 경상남도 진주시 카페온
# 별점
# 4.02
# --------------------
# 0 경상남도 진주시 서정골한우촌
# 별점
# 4.47
# --------------------
# 별점없음
# --------------------
# 0 경상남도 진주시 7080짜장짬뽕
# 별점
# 4.26
# --------------------
# 별점없음
# --------------------
# 0 경상남도 사천시 바른국수
# 방문자리뷰 1
# --------------------
# 0 경상남도 남해군 오대박찐빵
# 방문자리뷰 5
# --------------------
# 0 경상남도 남해군 남해 아라힐펜션
# 방문자리뷰 60
# --------------------
# 0 경상남도 남해군 해바리숯불장어구이
# 별점
# 4.01
# --------------------
# 0 경상남도 남해군 재두식당
# 별점
# 4.88
# --------------------
# 0 경상남도 통영시 산청봉냉면
# 방문자리뷰 21
# --------------------
# 0 경상남도 남해군 점심시간
# 방문자리뷰 7
# --------------------
# 별점없음
# --------------------
# 0 경상남도 통영시 금발헤어샵
# 방문자리뷰 13
# --------------------
# 별점없음
# --------------------
# 0 경상남도 통영시 김선생충무김밥
# 별점
# 4.29
# --------------------
# 0 경상남도 통영시 만나충무김밥
# 별점
# 4.29
# --------------------
# 0 경상남도 통영시 거림분식
# 블로그리뷰 8
# --------------------
# 0 경상남도 통영시 황소국밥
# 방문자리뷰 8
# --------------------
# 0 경상남도 통영시 통영아찌수제돈까스
# 방문자리뷰 117
# --------------------
# 0 경상남도 통영시 통영촌국수
# 별점
# 4.13
# --------------------
# 0 경상남도 통영시 금화먹거리
# 별점
# 3.82
# --------------------
# 0 경상남도 김해시 자아연토탈뷰티샵
# 별점
# 4.32
# --------------------
# 0 경상남도 통영시 수랏간
# 별점
# 4.43
# --------------------
# 0 경상남도 통영시 아지매보리밥
# 별점
# 4.74
# --------------------
# 0 경상남도 김해시 점이국수
# 방문자리뷰 27
# --------------------
# 0 경상남도 김해시 골목아구찜
# 별점
# 4.5
# --------------------
# 별점없음
# --------------------
# 0 경상남도 김해시 공원반점
# 별점
# 4.18
# --------------------
# 0 경상남도 김해시 엠제이 헤어샵
# 별점
# 4.27
# --------------------
# 0 경상남도 김해시 별미국수
# 별점
# 4.39
# --------------------
# 0 경상남도 김해시 영국수
# 별점
# 4.53
# --------------------
# 0 경상남도 김해시 고향밥상
# 방문자리뷰 215
# --------------------
# 0 경상남도 김해시 삼문곰탕
# 방문자리뷰 139
# --------------------
# 0 경상남도 김해시 반헤어
# 방문자리뷰 22
# --------------------
# 별점없음
# --------------------
# 0 경상남도 김해시 서진헤어
# 블로그리뷰 2
# --------------------
# 0 경상남도 김해시 김해 멸치국수
# 별점
# 4.34
# --------------------
# 0 경상남도 김해시 외가국수
# 별점
# 4.14
# --------------------
# 0 경상남도 김해시 양배추머리방
# 방문자리뷰 9
# --------------------
# 0 경상남도 김해시 카페샤론
# 방문자리뷰 29
# --------------------
# 0 경상남도 김해시 사리원밀면
# 방문자리뷰 1
# --------------------
# 별점없음
# --------------------
# 0 경상남도 사천시 대박국수
# 방문자리뷰 16
# --------------------
# 별점없음
# --------------------
# 0 경상남도 김해시 휴앤힐
# 방문자리뷰 19
# --------------------
# 별점없음
# --------------------
# 0 경상남도 김해시 모델헤어
# 방문자리뷰 12
# --------------------
# 0 경상남도 김해시 샤인헤어
# 방문자리뷰 17
# --------------------
# 0 경상남도 김해시 나경아미용실
# 방문자리뷰 4
# --------------------
# 0 경상남도 합천군 적교장
# 별점
# 4.27
# --------------------
# 0 경상남도 합천군 수림탕
# 방문자리뷰 1
# --------------------
# 0 경상남도 합천군 국수전문점
# 방문자리뷰 11
# --------------------
# 0 경상남도 합천군 드림모텔
# 방문자리뷰 13
# --------------------
# 0 경상남도 합천군 제우스모텔
# 별점
# 4.06
# --------------------
# 별점없음
# --------------------
# 0 경상남도 남해군 어울림꿈뜨락협동조합
# 방문자리뷰 7
# --------------------
# 별점없음
# --------------------
# 0 경상남도 진주시 바른돈까스 혁신직영
# 방문자리뷰 14
# --------------------
# 0 경상남도 남해군 다선정
# 별점
# 4.53
# --------------------
# 0 경상남도 김해시 불티난호떡
# 별점
# 4.29
# --------------------
# 0 경상남도 김해시 더진짬뽕
# 별점
# 4.48
# --------------------
# 0 경상남도 김해시 남포통닭
# 별점
# 4.49
# --------------------
# 0 경상남도 김해시 짱구왕만두
# 별점
# 4.52
# --------------------
# 0 경상남도 김해시 대가양곱창
# 별점
# 4.42
# --------------------
# 0 경상남도 김해시 한일뒷고기
# 별점
# 4.25
# --------------------
# 0 경상남도 김해시 사철제면소
# 방문자리뷰 108
# --------------------
# 0 경상남도 김해시 돼지꿈
# 별점
# 4.74
# --------------------
# 0 경상남도 김해시 무한리필삼겹천하
# 별점
# 4.64
# --------------------
# 0 경상남도 김해시 장터국수선지국밥
# 방문자리뷰 20
# --------------------
# 0 경상남도 거제시 언니다방
# 별점
# 4.59
# --------------------
# 0 경상남도 진주시 커피콩
# 방문자리뷰 16
# --------------------
# 0 경상남도 통영시 123충무김밥
# 별점
# 4.2
# --------------------
# 별점없음
# --------------------
# 0 경상남도 양산시 시골장터 돼지국밥
# 방문자리뷰 63
# --------------------
# 0 경상남도 고성군 명진밥상
# 방문자리뷰 52
# --------------------
# 0 경상남도 고성군 오시오식당
# 별점
# 4.2
# --------------------
# 0 경상남도 고성군 고성공룡시장휴게소
# 별점
# 4.56
# --------------------
# 0 경상남도 고성군 보현네 대박집
# 별점
# 4.67
# --------------------
# 0 경상남도 고성군 얼큰이손칼국수
# 별점
# 4.52
# --------------------
# 0 경상남도 고성군 장승골황토가
# 별점
# 4.71
# --------------------
# 0 경상남도 거제시 하오츠
# 별점
# 4.58
# --------------------
# 별점없음
# --------------------
# 0 경상남도 거제시 용쓰네갈비
# 방문자리뷰 418
# --------------------
# 0 경상남도 창원시 시장분식
# 별점
# 4.5
# --------------------
# 0 경상남도 창원시 미가칼국수
# 방문자리뷰 6
# --------------------
# 0 경상남도 창원시 속천국밥
# 방문자리뷰 7
# --------------------
# 0 경상남도 창원시 대봉막창
# 방문자리뷰 139
# --------------------
# 0 경상남도 창원시 남양사진관
# 별점
# 4.6
# --------------------
# 0 경상남도 창원시 다복한식부페
# 별점
# 4.48
# --------------------
# 0 경상남도 창원시 메밀파티
# 별점
# 4.4
# --------------------
# 0 경상남도 창원시 AT비지니스호텔
# 별점
# 4.5
# --------------------
# 0 경상남도 창원시 옛날짜장면
# 별점
# 4.33
# --------------------
# 0 경상남도 밀양시 두레정 식당
# 방문자리뷰 26
# --------------------
# 0 경상남도 김해시 바보엄마칼국수
# 별점
# 4.47
# --------------------
# 별점없음
# --------------------
# 0 경상남도 김해시 커피쟁이
# 별점
# 4.33
# --------------------
# 0 경상남도 김해시 더부엌
# 별점
# 4.52
# --------------------
# 0 경상남도 김해시 장유백짜장
# 별점
# 4.02
# --------------------
# 별점없음
# --------------------
# 0 경상남도 김해시 야래향
# 별점
# 4.47
# --------------------
# 0 경상남도 김해시 하루만
# 별점
# 4.51
# --------------------
# 0 경상남도 김해시 오뚝이바지락반칼국수반
# 방문자리뷰 527
# --------------------
# 0 경상남도 김해시 김해만두만리향
# 별점
# 4.56
# --------------------
# 별점없음
# --------------------
# 0 경상남도 김해시 아리랑토속집밥
# 별점
# 4.37
# --------------------
# 0 경상남도 밀양시 밀양가야밀면
# 별점
# 4.21
# --------------------
# 0 경상남도 김해시 사량도
# 별점
# 4.33
# --------------------
# 0 경상남도 김해시 해룡
# 별점
# 4.2
# --------------------
# 0 경상남도 김해시 한끼김밥
# 별점
# 4.44
# --------------------
# 0 경상남도 김해시 박수민헤어샵
# 방문자리뷰 10
# --------------------
# 0 경상남도 김해시 오칠컷트(5.7컷트)
# 방문자리뷰 7
# --------------------
# 0 경상남도 통영시 풍화루
# 방문자리뷰 14
# --------------------
# 0 경상남도 통영시 한성충무김밥
# 별점
# 4.68
# --------------------
# 별점없음
# --------------------
# 0 경상남도 밀양시 솔밭만두
# 별점
# 4.39
# --------------------
# 0 경상남도 밀양시 서연식당
# 별점
# 4.11
# --------------------
# 별점없음
# --------------------
# 0 경상남도 창원시 화성갈비
# 별점
# 4.17
# --------------------
# 별점없음
# --------------------
# 0 경상남도 밀양시 금천스파
# 별점
# 4.54
# --------------------
# 0 경상남도 창원시 복개천감자탕
# 별점
# 4.48
# --------------------
# 0 경상남도 창원시 미송스킨케어
# 방문자리뷰 43
# --------------------
# 별점없음
# --------------------
# 0 경상남도 창원시 전주국밥
# 별점
# 4.68
# --------------------
# 별점없음
# --------------------
# 0 경상남도 합천군 덕화반점
# 별점
# 4.58
# --------------------
# 0 경상남도 합천군 주연이국밥
# 방문자리뷰 60
# --------------------
# 0 경상남도 합천군 청학동식당
# 별점
# 4.53
# --------------------
# 0 경상남도 합천군 통영추어탕
# 방문자리뷰 15
# --------------------
# 별점없음
# --------------------
# 0 경상남도 창원시 마산실내운전연습장
# 방문자리뷰 5
# --------------------
# 0 경상남도 창원시 낙동강오리가든
# 방문자리뷰 65
# --------------------
# 0 경상남도 창원시 포청관
# 별점
# 4.43
# --------------------
# 0 경상남도 창원시 엄마식당
# 방문자리뷰 2
# --------------------
# 0 경상남도 창원시 진해제과
# 별점
# 4.29
# --------------------
# 0 경상남도 창원시 미진과자점
# 방문자리뷰 634
# --------------------
# 0 경상남도 창원시 진경숯불갈비
# 별점
# 4.3
# --------------------
# 별점없음
# --------------------
# 0 경상남도 창원시 반달집
# 방문자리뷰 28
# --------------------
# 0 경상남도 창원시 불로식당
# 별점
# 4.67
# --------------------
# 0 경상남도 창원시 꽃핀(식육식당)
# 별점
# 4.77
# --------------------
# 0 경상남도 남해군 아구마을
# 별점
# 4.39
# --------------------
# 0 경상남도 창원시 중앙분식
# 별점
# 4.24
# --------------------
# 별점없음
# --------------------
# 0 경상남도 창원시 소반
# 별점
# 4.36
# --------------------
# 0 경상남도 창원시 우정분식식당
# 방문자리뷰 3
# --------------------
# 별점없음
# --------------------
# 0 경상남도 창원시 고인돌
# 별점
# 4.59
# --------------------
# 0 경상남도 창원시 새맛정식당
# 방문자리뷰 5
# --------------------
# 0 경상남도 창원시 부산제과
# 별점
# 4.37
# --------------------
# 0 경상남도 창원시 유크리닝
# 별점
# 4.11
# --------------------
# 별점없음
# --------------------
# 0 경상남도 창원시 메밀한판
# 별점
# 4.47
# --------------------
# 0 경상남도 김해시 끼니와분식
# 별점
# 4.58
# --------------------
# 0 경상남도 합천군 대가한우
# 별점
# 4.5
# --------------------
# 0 경상남도 합천군 다라국수
# 별점
# 4.3
# --------------------
# 0 경상남도 밀양시 전통손칼국수
# 방문자리뷰 36
# --------------------
# 0 경상남도 밀양시 아리랑돼지국밥
# 별점
# 4.41
# --------------------
# 0 경상남도 밀양시 삼랑진소머리곰탕
# 방문자리뷰 313
# --------------------
# 0 경상남도 창원시 전통곰탕
# 방문자리뷰 174
# --------------------
# 0 경상남도 거창군 착한한돈
# 방문자리뷰 222
# --------------------
# 0 경상남도 거제시 여우들의쉼터 미용실
# 방문자리뷰 3
# --------------------
# 0 경상남도 거제시 야생화편지
# 방문자리뷰 31
# --------------------
# 0 경상남도 김해시 엔젤플러스헤어샵
# 별점
# 4.25
# --------------------
# 0 경상남도 김해시 쌈마이
# 방문자리뷰 126
# --------------------
# 별점없음
# --------------------
# 0 경상남도 김해시 만리장성&가야밀면
# 별점
# 4.27
# --------------------
# 0 경상남도 김해시 굿모닝시락국
# 방문자리뷰 31
# --------------------
# 0 경상남도 김해시 삼정탕
# 방문자리뷰 2
# --------------------
# 0 경상남도 창원시 호호돼지국밥
# 별점
# 4.59
# --------------------
# 0 경상남도 진주시 다모아헤어
# 방문자리뷰 13
# --------------------
# 별점없음
# --------------------
# 0 경상남도 김해시 봉평메밀마당
# 별점
# 4.38
# --------------------
# 0 경상남도 김해시 도도플레이트
# 별점
# 4.57
# --------------------
# 별점없음
# --------------------
# 0 경상남도 김해시 상해루
# 별점
# 4.19
# --------------------
# 0 경상남도 김해시 필가지짜장
# 별점
# 4.4
# --------------------
# 0 경상남도 김해시 교동짬뽕
# 방문자리뷰 1,108
# --------------------
# 0 경상남도 김해시 용복사
# 별점
# 4.22
# --------------------
# 0 경상남도 김해시 윤짱카레
# 별점
# 4.6
# --------------------
# 0 경상남도 김해시 의령할머니소고기국밥
# 별점
# 4.6
# --------------------
# 별점없음
# --------------------
# 0 경상남도 김해시 고기굽는 아저씨
# 방문자리뷰 61
# --------------------
# 0 경상남도 김해시 안커피하우스
# 별점
# 4.59
# --------------------
# 0 경상남도 김해시 심술민경포차
# 방문자리뷰 372
# --------------------
# 0 경상남도 김해시 꼬꼬파티
# 별점
# 4.88
# --------------------
# 0 경상남도 김해시 몽실이칼국수
# 별점
# 4.41
# --------------------
# 0 경상남도 김해시 착한대구탕
# 별점
# 4.73
# --------------------
# 0 경상남도 김해시 먹꼬가자
# 별점
# 4.34
# --------------------
# 0 경상남도 밀양시 전통밀면
# 별점
# 4.33
# --------------------
# 0 경상남도 김해시 Dr.닭터
# 별점
# 4.77
# --------------------
# 별점없음
# --------------------
# 0 경상남도 밀양시 대청정
# 방문자리뷰 33
# --------------------
# 0 경상남도 밀양시 참콩나물해장국
# 별점
# 4.43
# --------------------
# 0 경상남도 밀양시 경일루반점
# 별점
# 4
# --------------------
# 0 경상남도 밀양시 신갈매기
# 방문자리뷰 79
# --------------------
# 0 경상남도 밀양시 장터민물장어
# 방문자리뷰 30
# --------------------
# 0 경상남도 밀양시 건강국수
# 방문자리뷰 29
# --------------------
# 0 경상남도 밀양시 춘하추동
# 별점
# 4.06
# --------------------
# 0 경상남도 밀양시 깡통분식
# 방문자리뷰 5
# --------------------
# 0 경상남도 밀양시 일품식당
# 블로그리뷰 1
# --------------------
# 0 경상남도 고성군 배꼭지
# 별점
# 4.14
# --------------------
# 별점없음
# --------------------
# 0 경상남도 거제시 기사식당
# 별점
# 4.47
# --------------------
# 0 경상남도 거제시 거제냉밀면
# 별점
# 4.47
# --------------------
# 0 경상남도 거제시 지중해
# 별점
# 4.53
# --------------------
# 0 경상남도 거제시 바다친구
# 별점
# 3.95
# --------------------
# 별점없음
# --------------------
# 0 경상남도 창녕군 남지철교돼지국밥
# 별점
# 4.33
# --------------------
# 0 경상남도 함양군 코코기린
# 별점
# 4.57
# --------------------
# 0 경상남도 함양군 옛날보리밥집
# 방문자리뷰 1
# --------------------
# 0 경상남도 거창군 영민분식
# 블로그리뷰 2
# --------------------
# 0 경상남도 함안군 띵호반점
# 별점
# 4.6
# --------------------
# 0 경상남도 거제시 K-BS헤어뉴스
# 별점
# 4.31
# --------------------
# 0 경상남도 통영시 이순신충무김밥
# 별점
# 4.32
# --------------------
# 0 경상남도 진주시 빠삭돈가스
# 별점
# 4.58
# --------------------
# 0 경상남도 함양군 복성각
# 방문자리뷰 18
# --------------------
# 별점없음
# --------------------
# 0 경상남도 밀양시 쌈지
# 방문자리뷰 14
# --------------------
# 별점없음
# --------------------
# 별점없음
# --------------------
# 0 경상남도 진주시 산수골
# 별점
# 4.46
# --------------------
# 0 경상남도 진주시 미스터돈가스
# 별점
# 4.29
# --------------------
# 0 경상남도 김해시 금강미용실
# 방문자리뷰 9
# --------------------
# 0 경상남도 김해시 주가네돼지국밥
# 방문자리뷰 48
# --------------------
# 0 경상남도 하동군 여명가든
# 별점
# 4.65
# --------------------
# 0 경상남도 김해시 고기박사
# 별점
# 4.51
# --------------------
# 0 경상남도 김해시 고기예찬
# 별점
# 4.44
# --------------------
# 별점없음
# --------------------
# 0 경상남도 김해시 두레박
# 별점
# 4.37
# --------------------
# 0 경상남도 김해시 서연멸치쌈밥
# 별점
# 4.25
# --------------------
# 0 경상남도 김해시 내삼반점
# 별점
# 4.32
# --------------------
# 0 경상남도 합천군 삼가명품한우
# 별점
# 4.36
# --------------------
# 0 경상남도 합천군 연하정
# 별점
# 4.29
# --------------------
# 0 경상남도 합천군 수미정식당
# 별점
# 4.41
# --------------------
# 0 경상남도 합천군 옥산식육식당
# 별점
# 4.5
# --------------------
# 0 경상남도 창녕군 맘보식당
# 방문자리뷰 10
# --------------------
# 0 경상남도 합천군 세진숯불갈비
# 별점
# 4.56
# --------------------
# 0 경상남도 하동군 원조재첩국나루터식당
# 별점
# 4.18
# --------------------
# 0 경상남도 하동군 착한구이 식육식당
# 방문자리뷰 13
# --------------------
# 0 경상남도 함안군 솔마을
# 별점
# 4.35
# --------------------
# 0 경상남도 진주시 대복식당
# 별점
# 4.24
# --------------------
# 별점없음
# --------------------
# 0 경상남도 거창군 정가네오가네
# 방문자리뷰 36
# --------------------
# 별점없음
# --------------------
# 0 경상남도 거제시 청학횟집
# 별점
# 4.08
# --------------------
# 0 경상남도 창원시 임진각
# 방문자리뷰 3,072
# --------------------
# 0 경상남도 통영시 이모손충무김밥
# 별점
# 4.31
# --------------------
# 별점없음
# --------------------
# 0 경상남도 남해군 복례가마솥국밥
# 별점
# 4.29
# --------------------
# 0 경상남도 남해군 하늬바람
# 방문자리뷰 25
# --------------------
# 0 경상남도 창원시 쟁반뒷고기
# 별점
# 4.63
# --------------------
# 0 경상남도 창원시 선우돌판구이
# 별점
# 4.47
# --------------------
# 별점없음
# --------------------
# 0 경상남도 창원시 두현성
# 방문자리뷰 54
# --------------------
# 0 경상남도 창원시 소원식당
# 별점
# 4.74
# --------------------
# 별점없음
# --------------------
# 0 경상남도 창녕군 까망머리방
# 방문자리뷰 13
# --------------------
# 0 경상남도 창녕군 홍천뚝배기
# 별점
# 4.43
# --------------------
# 0 경상남도 통영시 나포리충무김밥
# 별점
# 4.24
# --------------------
# 0 경상남도 남해군 설천죽집
# 방문자리뷰 432
# --------------------
# 0 경상남도 김해시 돈황
# 별점
# 4.33
# --------------------
# 0 경상남도 거제시 노자산묵밥집
# 별점
# 4.4
# --------------------
# 0 경상남도 거제시 쿠아미용실
# 별점
# 4.7
# --------------------
# 0 경상남도 거제시 행운식당
# 방문자리뷰 11
# --------------------
# 0 경상남도 거제시 서울식당
# 별점
# 4.09
# --------------------
# 0 경상남도 거제시 남영식당
# 방문자리뷰 4
# --------------------
# 0 경상남도 거제시 무등산식당
# 별점
# 4.2
# --------------------
# 별점없음
# --------------------
# 0 경상남도 산청군 아리산반점
# 별점
# 4.51
# --------------------
# 0 경상남도 함안군 거북이식당
# 별점
# 4.25
# --------------------
# 0 경상남도 창원시 착한멸치국수
# 별점
# 4.56
# --------------------
# 별점없음
# --------------------
# 0 경상남도 합천군 행복한 목욕탕
# 방문자리뷰 24
# --------------------
# 0 경상남도 창원시 합천식당
# 방문자리뷰 1
# --------------------
# 0 경상남도 창원시 빅보이분식
# 방문자리뷰 39
# --------------------
# 별점없음
# --------------------
# 0 경상남도 창원시 이화원(효동각)
# 별점
# 4.22
# --------------------
# 0 경상남도 창원시 성안숯불갈비(성안식당)
# 별점
# 4.29
# --------------------
# 0 경상남도 창원시 유니온식육식당
# 별점
# 4.4
# --------------------
# 0 경상남도 창원시 삼포복집
# 별점
# 4.31
# --------------------
# 별점없음
# --------------------
# 0 경상남도 합천군 금호관
# 방문자리뷰 138
# --------------------
# 0 경상남도 합천군 돈먹쇠숯불갈비
# 별점
# 4.12
# --------------------
# 0 경상남도 합천군 중앙식육식당
# 별점
# 3.93
# --------------------
# 별점없음
# --------------------
# 별점없음
# --------------------
# 별점없음
# --------------------
# 0 경상남도 함양군 그린식당
# 별점
# 4.34
# --------------------
# 0 경상남도 함양군 도야낙지
# 별점
# 4.12
# --------------------
# 0 경상남도 함양군 늘봄가든
# 방문자리뷰 769
# --------------------
# 0 경상남도 함양군 숙이분식
# 방문자리뷰 11
# --------------------
# 0 경상남도 함양군 옥호식당
# 별점
# 4.03
# --------------------
# 0 경상남도 함양군 도라지식당
# 방문자리뷰 30
# --------------------
# 별점없음
# --------------------
# 0 경상남도 함양군 연밭식육식당
# 별점
# 4.36
# --------------------
# 0 경상남도 함양군 만월식당
# 별점
# 4.35
# --------------------
# 0 경상남도 통영시 태평숯불갈비
# 방문자리뷰 12
# --------------------
# 별점없음
# --------------------
# 0 경상남도 함안군 한흥목욕탕
# 방문자리뷰 4
# --------------------
# 0 경상남도 함안군 광천식당
# 방문자리뷰 3
# --------------------
# 0 경상남도 함안군 사랑채
# 별점
# 4.33
# --------------------
# 0 경상남도 함안군 아라정식육식당
# 별점
# 4.56
# --------------------
# 0 경상남도 함안군 솔밭가든
# 별점
# 4.5
# --------------------
# 0 경상남도 하동군 금성숯불갈비
# 방문자리뷰 18
# --------------------
# 별점없음
# --------------------
# 0 경상남도 하동군 하동솔잎한우프라자
# 별점
# 4.28
# --------------------
# 0 경상남도 하동군 해성식당
# 별점
# 4.2
# --------------------
# 0 경상남도 통영시 풍성한충무김밥
# 별점
# 4.07
# --------------------
# 별점없음
# --------------------
# 0 경상남도 통영시 충무김밥케이블카점
# 별점
# 4.14
# --------------------
# 0 경상남도 통영시 원조충무할매김밥
# 별점
# 4.28
# --------------------
# 0 경상남도 통영시 본가할매김밥
# 방문자리뷰 30
# --------------------
# 0 경상남도 통영시 동피랑김밥
# 별점
# 4.31
# --------------------
# 별점없음
# --------------------
# 0 경상남도 창원시 대도식당
# 방문자리뷰 160
# --------------------
# 0 경상남도 창원시 월성식당
# 방문자리뷰 8
# --------------------
# 0 경상남도 창원시 옛날촌국수집
# 방문자리뷰 40
# --------------------
# 0 경상남도 창원시 새마을찌게나라
# 별점
# 4.29
# --------------------
# 별점없음
# --------------------
# 0 경상남도 창원시 동촌(손)칼국수
# 별점
# 4.25
# --------------------
# 0 경상남도 진주시 현대식육식당
# 별점
# 4.45
# --------------------
# 0 경상남도 창원시 경성국밥
# 별점
# 4.33
# --------------------
# 0 경상남도 창원시 일신세탁
# 방문자리뷰 4
# --------------------
# 0 경상남도 창원시 낙동추어탕
# 별점
# 4.02
# --------------------
# 0 경상남도 창원시 구구장어구이식당
# 별점
# 4.4
# --------------------
# 0 경상남도 창원시 종로돼지국밥
# 별점
# 4.34
# --------------------
# 0 경상남도 창원시 오리둥지
# 별점
# 4.18
# --------------------
# 0 경상남도 창녕군 번개반점
# 방문자리뷰 8
# --------------------
# 별점없음
# --------------------
# 0 경상남도 진주시 삼가한우소리
# 별점
# 4.29
# --------------------
# 별점없음
# --------------------
# 0 경상남도 진주시 세심천탕
# 방문자리뷰 7
# --------------------
# 별점없음
# --------------------
# 별점없음
# --------------------
# 0 경상남도 의령군 양평해장국
# 별점
# 4.34
# --------------------
# 0 경상남도 의령군 울산식당
# 방문자리뷰 7
# --------------------
# 0 경상남도 의령군 승희네분식
# 방문자리뷰 38
# --------------------
# 0 경상남도 의령군 송림가든
# 별점
# 4.21
# --------------------
# 0 경상남도 의령군 시장아구찜
# 방문자리뷰 2
# --------------------
# 0 경상남도 의령군 의령화정소바
# 별점
# 4.41
# --------------------
# 0 경상남도 의령군 평화원
# 별점
# 4.06
# --------------------
# 0 경상남도 의령군 한영식당
# 방문자리뷰 75
# --------------------
# 0 경상남도 의령군 토방분식
# 별점
# 4.45
# --------------------
# 0 경상남도 의령군 진성보쌈
# 별점
# 4.43
# --------------------
# 0 경상남도 사천시 통큰치킨
# 별점
# 4.64
# --------------------
# 0 경상남도 양산시 대장금
# 별점
# 4.41
# --------------------
# 별점없음
# --------------------
# 0 경상남도 양산시 까스방
# 별점
# 4.68
# --------------------
# 0 경상남도 양산시 낙지발이몇개고
# 별점
# 4.35
# --------------------
# 0 경상남도 양산시 본가중화요리
# 별점
# 4.42
# --------------------
# 0 경상남도 양산시 고기세상숯불갈비
# 별점
# 4.05
# --------------------
# 0 경상남도 산청군 모든분식
# 방문자리뷰 2
# --------------------
# 0 경상남도 산청군 정원쌈밥
# 별점
# 4.22
# --------------------
# 0 경상남도 사천시 킴미용실
# 방문자리뷰 1
# --------------------
# 별점없음
# --------------------
# 별점없음
# --------------------
# 0 경상남도 밀양시 가마솥추어탕
# 별점
# 4.21
# --------------------
# 0 경상남도 사천시 장터분식
# 방문자리뷰 16
# --------------------
# 0 경상남도 사천시 사천촌국수
# 방문자리뷰 13
# --------------------
# 0 경상남도 사천시 예지분식
# 방문자리뷰 64
# --------------------
# 0 경상남도 사천시 시장국수
# 블로그리뷰 4
# --------------------
# 0 경상남도 사천시 제일국수
# 별점
# 4.38
# --------------------
# 별점없음
# --------------------
# 0 경상남도 밀양시 헤어 ll
# 방문자리뷰 10
# --------------------
# 0 경상남도 밀양시 도도국밥
# 방문자리뷰 49
# --------------------
# 별점없음
# --------------------
# 0 경상남도 밀양시 동아리
# 방문자리뷰 4
# --------------------
# 별점없음
# --------------------
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# Cell In[3], line 105
#     102         driver.switch_to.default_content()
#     103 #        time.sleep(s_dt)
# --> 105         c_btn = driver.find_element(By.XPATH,'//*[@id="app-layout"]/div[1]/div/div[1]/div/div/button[2]')
#     106         c_btn.click()
#     107 #        time.sleep(s_dt)
#
# File c:\Users\GJ\AppData\Local\Programs\Python\Python312\Lib\site-packages\selenium\webdriver\remote\webdriver.py:742, in WebDriver.find_element(self, by, value)
#     739     by = By.CSS_SELECTOR
#     740     value = f'[name="{value}"]'
# --> 742 return self.execute(Command.FIND_ELEMENT, {"using": by, "value": value})["value"]
#
# File c:\Users\GJ\AppData\Local\Programs\Python\Python312\Lib\site-packages\selenium\webdriver\remote\webdriver.py:348, in WebDriver.execute(self, driver_command, params)
#     346 response = self.command_executor.execute(driver_command, params)
#     347 if response:
# --> 348     self.error_handler.check_response(response)
#     349     response["value"] = self._unwrap_value(response.get("value", None))
#     350     return response
#
# File c:\Users\GJ\AppData\Local\Programs\Python\Python312\Lib\site-packages\selenium\webdriver\remote\errorhandler.py:229, in ErrorHandler.check_response(self, response)
#     227         alert_text = value["alert"].get("text")
#     228     raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 229 raise exception_class(message, screen, stacktrace)
#
# NoSuchElementException: Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="app-layout"]/div[1]/div/div[1]/div/div/button[2]"}
#   (Session info: chrome=120.0.6099.110); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# 	GetHandleVerifier [0x00007FF717E72142+3514994]
# 	(No symbol) [0x00007FF717A90CE2]
# 	(No symbol) [0x00007FF7179376AA]
# 	(No symbol) [0x00007FF717981860]
# 	(No symbol) [0x00007FF71798197C]
# 	(No symbol) [0x00007FF7179C4EE7]
# 	(No symbol) [0x00007FF7179A602F]
# 	(No symbol) [0x00007FF7179C28F6]
# 	(No symbol) [0x00007FF7179A5D93]
# 	(No symbol) [0x00007FF717974BDC]
# 	(No symbol) [0x00007FF717975C64]
# 	GetHandleVerifier [0x00007FF717E9E16B+3695259]
# 	GetHandleVerifier [0x00007FF717EF6737+4057191]
# 	GetHandleVerifier [0x00007FF717EEE4E3+4023827]
# 	GetHandleVerifier [0x00007FF717BC04F9+689705]
# 	(No symbol) [0x00007FF717A9C048]
# 	(No symbol) [0x00007FF717A98044]
# 	(No symbol) [0x00007FF717A981C9]
# 	(No symbol) [0x00007FF717A888C4]
# 	BaseThreadInitThunk [0x00007FF8D3FF7614+20]
# 	RtlUserThreadStart [0x00007FF8D57426B1+33]

# %%
result_L
# Out:
# ['별점없음', '별점없음', '별점없음', '별점없음', '별점없음', '별점없음', '방문자리뷰 43', '별점없음']

# %%
url = 'https://map.naver.com/p?c=15.00,0,0,0,dh'
driver = webdriver.Chrome() 
driver.get(url)
time.sleep(2)

# %%
driver.switch_to.default_content()
search_btn = driver.find_element(By.CSS_SELECTOR, 'div.input_box > input.input_search')
search_btn.click()

# %%
search_btn.send_keys('서울특별시 송파구 봉피양 별관')

# %%
search_btn.send_keys(Keys.ENTER)

# %%
driver.switch_to.frame('searchIframe')

# %%
item_btn = driver.find_element(By.XPATH,'//*[@id="_pcmap_list_scroll_container"]/ul/li[1]/div/div/a')
item_btn.click()

# %%
driver.switch_to.default_content()

# %%
driver.switch_to.frame('entryIframe')

# %%
item = driver.find_element(By.CSS_SELECTOR,'#app-root > div > div > div > div:nth-child(2) > div:nth-child(1) > div:nth-child(2) > span:nth-child(1)')

# %%
item.text
# Out:
# '별점\n4.78'

# %%
driver.switch_to.default_content()

# %%
c_btn = driver.find_element(By.XPATH,'//*[@id="app-layout"]/div[1]/div/div[1]/div/div/button[2]')

# %%
c_btn.click()

# %%
df = pd.read_csv('C:\python-workspace\mini_pj\Seoul.csv')
df
# Out:
#       Unnamed: 0     업종       업소명        주요품목      가격             연락처  \
# 0              0  한식_육류      신원식당         삼겹살  16000원    02-3394-5121
# 1              1  한식_일반    신미가 맛집        한식부페   7000원  0507-1366-1326
# 2              2  한식_일반  북한산 손칼국수        손칼국수   5500원  0507-1407-4413
# 3              3  한식_일반     응암칼국수       삼겹순대국   8000원     02-918-6700
# 4              4  한식_일반    따뜻한 밥상        김치찌개   3000원     02-000-0000
# ...          ...    ...       ...         ...     ...             ...
# 1017        1017  한식_일반     시골청국장         청국장   8000원     02-548-0171
# 1018        1018  한식_일반      해남식당         청국장   8000원     02-543-9660
# 1019        1019  한식_일반       지리산         닭곰탕   9000원     02-546-3127
# 1020        1020   이미용업     선경헤어샵          커트  12000원     02-566-3019
# 1021        1021  한식_육류  청송숯불화로구이  돼지갈비(250g)  20000원     02-549-3739
#
#                                         주소
# 0     서울특별시 동대문구 장한로 92, 101호  (장안동, 화성빌딩)
# 1          서울특별시 은평구 서울특별시 은평구 증산로15길 24-1
# 2               서울특별시 은평구 서울특별시 은평구 대서문길36
# 3          서울특별시 은평구 서울특별시 은평구 응암로21길 18-1
# 4          서울특별시 은평구 서울특별시 은평구 연서로 260, 2층
# ...                                    ...
# 1017           서울특별시 강남구 학동로 504 서울빌딩 101호
# 1018   서울특별시 강남구 학동로101길 26 청담삼익상가 지하1층 4호
# 1019               서울특별시 강남구 학동로43길 7 지상1층
# 1020       서울특별시 강남구 삼성로 151 선경상가 지하1층 13호
# 1021                 서울특별시 강남구 언주로 114길 17
#
# [1022 rows x 7 columns]

# %%
df.columns=('0','업종','업소명','주요품목','가격','연락처','주소')
df
# Out:
#          0     업종       업소명        주요품목      가격             연락처  \
# 0        0  한식_육류      신원식당         삼겹살  16000원    02-3394-5121
# 1        1  한식_일반    신미가 맛집        한식부페   7000원  0507-1366-1326
# 2        2  한식_일반  북한산 손칼국수        손칼국수   5500원  0507-1407-4413
# 3        3  한식_일반     응암칼국수       삼겹순대국   8000원     02-918-6700
# 4        4  한식_일반    따뜻한 밥상        김치찌개   3000원     02-000-0000
# ...    ...    ...       ...         ...     ...             ...
# 1017  1017  한식_일반     시골청국장         청국장   8000원     02-548-0171
# 1018  1018  한식_일반      해남식당         청국장   8000원     02-543-9660
# 1019  1019  한식_일반       지리산         닭곰탕   9000원     02-546-3127
# 1020  1020   이미용업     선경헤어샵          커트  12000원     02-566-3019
# 1021  1021  한식_육류  청송숯불화로구이  돼지갈비(250g)  20000원     02-549-3739
#
#                                         주소
# 0     서울특별시 동대문구 장한로 92, 101호  (장안동, 화성빌딩)
# 1          서울특별시 은평구 서울특별시 은평구 증산로15길 24-1
# 2               서울특별시 은평구 서울특별시 은평구 대서문길36
# 3          서울특별시 은평구 서울특별시 은평구 응암로21길 18-1
# 4          서울특별시 은평구 서울특별시 은평구 연서로 260, 2층
# ...                                    ...
# 1017           서울특별시 강남구 학동로 504 서울빌딩 101호
# 1018   서울특별시 강남구 학동로101길 26 청담삼익상가 지하1층 4호
# 1019               서울특별시 강남구 학동로43길 7 지상1층
# 1020       서울특별시 강남구 삼성로 151 선경상가 지하1층 13호
# 1021                 서울특별시 강남구 언주로 114길 17
#
# [1022 rows x 7 columns]

# %%
df.drop('0',axis=1,inplace=True)

# %%
df
# Out:
#          업종       업소명        주요품목      가격             연락처  \
# 0     한식_육류      신원식당         삼겹살  16000원    02-3394-5121
# 1     한식_일반    신미가 맛집        한식부페   7000원  0507-1366-1326
# 2     한식_일반  북한산 손칼국수        손칼국수   5500원  0507-1407-4413
# 3     한식_일반     응암칼국수       삼겹순대국   8000원     02-918-6700
# 4     한식_일반    따뜻한 밥상        김치찌개   3000원     02-000-0000
# ...     ...       ...         ...     ...             ...
# 1017  한식_일반     시골청국장         청국장   8000원     02-548-0171
# 1018  한식_일반      해남식당         청국장   8000원     02-543-9660
# 1019  한식_일반       지리산         닭곰탕   9000원     02-546-3127
# 1020   이미용업     선경헤어샵          커트  12000원     02-566-3019
# 1021  한식_육류  청송숯불화로구이  돼지갈비(250g)  20000원     02-549-3739
#
#                                         주소
# 0     서울특별시 동대문구 장한로 92, 101호  (장안동, 화성빌딩)
# 1          서울특별시 은평구 서울특별시 은평구 증산로15길 24-1
# 2               서울특별시 은평구 서울특별시 은평구 대서문길36
# 3          서울특별시 은평구 서울특별시 은평구 응암로21길 18-1
# 4          서울특별시 은평구 서울특별시 은평구 연서로 260, 2층
# ...                                    ...
# 1017           서울특별시 강남구 학동로 504 서울빌딩 101호
# 1018   서울특별시 강남구 학동로101길 26 청담삼익상가 지하1층 4호
# 1019               서울특별시 강남구 학동로43길 7 지상1층
# 1020       서울특별시 강남구 삼성로 151 선경상가 지하1층 13호
# 1021                 서울특별시 강남구 언주로 114길 17
#
# [1022 rows x 6 columns]

# %%
def check_add(word):
    w_L = []
    for w in word.split():
        if w not in w_L:
            w_L.append(w)
    return ' '.join(w_L)

# %%
df['수정주소'] =  df['주소'].apply(lambda x : check_add(x))
df
# Out:
#          업종       업소명        주요품목      가격             연락처  \
# 0     한식_육류      신원식당         삼겹살  16000원    02-3394-5121
# 1     한식_일반    신미가 맛집        한식부페   7000원  0507-1366-1326
# 2     한식_일반  북한산 손칼국수        손칼국수   5500원  0507-1407-4413
# 3     한식_일반     응암칼국수       삼겹순대국   8000원     02-918-6700
# 4     한식_일반    따뜻한 밥상        김치찌개   3000원     02-000-0000
# ...     ...       ...         ...     ...             ...
# 1017  한식_일반     시골청국장         청국장   8000원     02-548-0171
# 1018  한식_일반      해남식당         청국장   8000원     02-543-9660
# 1019  한식_일반       지리산         닭곰탕   9000원     02-546-3127
# 1020   이미용업     선경헤어샵          커트  12000원     02-566-3019
# 1021  한식_육류  청송숯불화로구이  돼지갈비(250g)  20000원     02-549-3739
#
#                                         주소  \
# 0     서울특별시 동대문구 장한로 92, 101호  (장안동, 화성빌딩)
# 1          서울특별시 은평구 서울특별시 은평구 증산로15길 24-1
# 2               서울특별시 은평구 서울특별시 은평구 대서문길36
# 3          서울특별시 은평구 서울특별시 은평구 응암로21길 18-1
# 4          서울특별시 은평구 서울특별시 은평구 연서로 260, 2층
# ...                                    ...
# 1017           서울특별시 강남구 학동로 504 서울빌딩 101호
# 1018   서울특별시 강남구 학동로101길 26 청담삼익상가 지하1층 4호
# 1019               서울특별시 강남구 학동로43길 7 지상1층
# 1020       서울특별시 강남구 삼성로 151 선경상가 지하1층 13호
# 1021                 서울특별시 강남구 언주로 114길 17
#
#                                      수정주소
# 0     서울특별시 동대문구 장한로 92, 101호 (장안동, 화성빌딩)
# 1                   서울특별시 은평구 증산로15길 24-1
# 2                        서울특별시 은평구 대서문길36
# 3                   서울특별시 은평구 응암로21길 18-1
# 4                   서울특별시 은평구 연서로 260, 2층
# ...                                   ...
# 1017          서울특별시 강남구 학동로 504 서울빌딩 101호
# 1018  서울특별시 강남구 학동로101길 26 청담삼익상가 지하1층 4호
# 1019              서울특별시 강남구 학동로43길 7 지상1층
# 1020      서울특별시 강남구 삼성로 151 선경상가 지하1층 13호
# 1021                서울특별시 강남구 언주로 114길 17
#
# [1022 rows x 7 columns]

# %%
check_add('서울특별시 은평구 서울특별시 은평구 대서문길36')
# Out:
# '서울특별시 은평구 대서문길36'

# %%
df
# Out:
#          업종       업소명        주요품목      가격             연락처  \
# 0     한식_육류      신원식당         삼겹살  16000원    02-3394-5121
# 1     한식_일반    신미가 맛집        한식부페   7000원  0507-1366-1326
# 2     한식_일반  북한산 손칼국수        손칼국수   5500원  0507-1407-4413
# 3     한식_일반     응암칼국수       삼겹순대국   8000원     02-918-6700
# 4     한식_일반    따뜻한 밥상        김치찌개   3000원     02-000-0000
# ...     ...       ...         ...     ...             ...
# 1017  한식_일반     시골청국장         청국장   8000원     02-548-0171
# 1018  한식_일반      해남식당         청국장   8000원     02-543-9660
# 1019  한식_일반       지리산         닭곰탕   9000원     02-546-3127
# 1020   이미용업     선경헤어샵          커트  12000원     02-566-3019
# 1021  한식_육류  청송숯불화로구이  돼지갈비(250g)  20000원     02-549-3739
#
#                                         주소  \
# 0     서울특별시 동대문구 장한로 92, 101호  (장안동, 화성빌딩)
# 1          서울특별시 은평구 서울특별시 은평구 증산로15길 24-1
# 2               서울특별시 은평구 서울특별시 은평구 대서문길36
# 3          서울특별시 은평구 서울특별시 은평구 응암로21길 18-1
# 4          서울특별시 은평구 서울특별시 은평구 연서로 260, 2층
# ...                                    ...
# 1017           서울특별시 강남구 학동로 504 서울빌딩 101호
# 1018   서울특별시 강남구 학동로101길 26 청담삼익상가 지하1층 4호
# 1019               서울특별시 강남구 학동로43길 7 지상1층
# 1020       서울특별시 강남구 삼성로 151 선경상가 지하1층 13호
# 1021                 서울특별시 강남구 언주로 114길 17
#
#                                      수정주소
# 0     서울특별시 동대문구 장한로 92, 101호 (장안동, 화성빌딩)
# 1                   서울특별시 은평구 증산로15길 24-1
# 2                        서울특별시 은평구 대서문길36
# 3                   서울특별시 은평구 응암로21길 18-1
# 4                   서울특별시 은평구 연서로 260, 2층
# ...                                   ...
# 1017          서울특별시 강남구 학동로 504 서울빌딩 101호
# 1018  서울특별시 강남구 학동로101길 26 청담삼익상가 지하1층 4호
# 1019              서울특별시 강남구 학동로43길 7 지상1층
# 1020      서울특별시 강남구 삼성로 151 선경상가 지하1층 13호
# 1021                서울특별시 강남구 언주로 114길 17
#
# [1022 rows x 7 columns]

# %%
df['검색어'] = df['수정주소'].apply(lambda x : x.split()[0]) + ' ' + df['수정주소'].apply(lambda x : x.split()[1]) + ' ' + df['업소명']
df
# Out:
#          업종       업소명        주요품목      가격             연락처  \
# 0     한식_육류      신원식당         삼겹살  16000원    02-3394-5121
# 1     한식_일반    신미가 맛집        한식부페   7000원  0507-1366-1326
# 2     한식_일반  북한산 손칼국수        손칼국수   5500원  0507-1407-4413
# 3     한식_일반     응암칼국수       삼겹순대국   8000원     02-918-6700
# 4     한식_일반    따뜻한 밥상        김치찌개   3000원     02-000-0000
# ...     ...       ...         ...     ...             ...
# 1017  한식_일반     시골청국장         청국장   8000원     02-548-0171
# 1018  한식_일반      해남식당         청국장   8000원     02-543-9660
# 1019  한식_일반       지리산         닭곰탕   9000원     02-546-3127
# 1020   이미용업     선경헤어샵          커트  12000원     02-566-3019
# 1021  한식_육류  청송숯불화로구이  돼지갈비(250g)  20000원     02-549-3739
#
#                                         주소  \
# 0     서울특별시 동대문구 장한로 92, 101호  (장안동, 화성빌딩)
# 1          서울특별시 은평구 서울특별시 은평구 증산로15길 24-1
# 2               서울특별시 은평구 서울특별시 은평구 대서문길36
# 3          서울특별시 은평구 서울특별시 은평구 응암로21길 18-1
# 4          서울특별시 은평구 서울특별시 은평구 연서로 260, 2층
# ...                                    ...
# 1017           서울특별시 강남구 학동로 504 서울빌딩 101호
# 1018   서울특별시 강남구 학동로101길 26 청담삼익상가 지하1층 4호
# 1019               서울특별시 강남구 학동로43길 7 지상1층
# 1020       서울특별시 강남구 삼성로 151 선경상가 지하1층 13호
# 1021                 서울특별시 강남구 언주로 114길 17
#
#                                      수정주소                 검색어
# 0     서울특별시 동대문구 장한로 92, 101호 (장안동, 화성빌딩)     서울특별시 동대문구 신원식당
# 1                   서울특별시 은평구 증산로15길 24-1    서울특별시 은평구 신미가 맛집
# 2                        서울특별시 은평구 대서문길36  서울특별시 은평구 북한산 손칼국수
# 3                   서울특별시 은평구 응암로21길 18-1     서울특별시 은평구 응암칼국수
# 4                   서울특별시 은평구 연서로 260, 2층    서울특별시 은평구 따뜻한 밥상
# ...                                   ...                 ...
# 1017          서울특별시 강남구 학동로 504 서울빌딩 101호     서울특별시 강남구 시골청국장
# 1018  서울특별시 강남구 학동로101길 26 청담삼익상가 지하1층 4호      서울특별시 강남구 해남식당
# 1019              서울특별시 강남구 학동로43길 7 지상1층       서울특별시 강남구 지리산
# 1020      서울특별시 강남구 삼성로 151 선경상가 지하1층 13호     서울특별시 강남구 선경헤어샵
# 1021                서울특별시 강남구 언주로 114길 17  서울특별시 강남구 청송숯불화로구이
#
# [1022 rows x 8 columns]

# %%
df.head(10)
# Out:
#       업종       업소명   주요품목      가격             연락처  \
# 0  한식_육류      신원식당    삼겹살  16000원    02-3394-5121
# 1  한식_일반    신미가 맛집   한식부페   7000원  0507-1366-1326
# 2  한식_일반  북한산 손칼국수   손칼국수   5500원  0507-1407-4413
# 3  한식_일반     응암칼국수  삼겹순대국   8000원     02-918-6700
# 4  한식_일반    따뜻한 밥상   김치찌개   3000원     02-000-0000
# 5    세탁업     새서울세탁  양복세탁료   7000원     02-814-8194
# 6  한식_일반  송천엄마손칼국수    칼국수   6000원     02-470-3370
# 7  한식_일반     방이뚝배기    청국장   4000원              없음
# 8    세탁업     새서울세탁  양복세탁료   7000원     02-814-8194
# 9  한식_분식    먹거리휴게소  옛날토스트   2000원     02-869-1318
#
#                                      주소                                 수정주소  \
# 0  서울특별시 동대문구 장한로 92, 101호  (장안동, 화성빌딩)  서울특별시 동대문구 장한로 92, 101호 (장안동, 화성빌딩)
# 1       서울특별시 은평구 서울특별시 은평구 증산로15길 24-1                서울특별시 은평구 증산로15길 24-1
# 2            서울특별시 은평구 서울특별시 은평구 대서문길36                     서울특별시 은평구 대서문길36
# 3       서울특별시 은평구 서울특별시 은평구 응암로21길 18-1                서울특별시 은평구 응암로21길 18-1
# 4       서울특별시 은평구 서울특별시 은평구 연서로 260, 2층                서울특별시 은평구 연서로 260, 2층
# 5              서울특별시 송파구 동남로 17길 11, 1층             서울특별시 송파구 동남로 17길 11, 1층
# 6               서울특별시 송파구 마천로 45길 8, 1층              서울특별시 송파구 마천로 45길 8, 1층
# 7               서울특별시 송파구 방이동 141-6, 1층              서울특별시 송파구 방이동 141-6, 1층
# 8                 서울특별시  동남로 17길 11, 1층                 서울특별시 동남로 17길 11, 1층
# 9    서울특별시 금천구 벚꽃로 309 (1호선 상행선 10-4 앞)   서울특별시 금천구 벚꽃로 309 (1호선 상행선 10-4 앞)
#
#                   검색어
# 0     서울특별시 동대문구 신원식당
# 1    서울특별시 은평구 신미가 맛집
# 2  서울특별시 은평구 북한산 손칼국수
# 3     서울특별시 은평구 응암칼국수
# 4    서울특별시 은평구 따뜻한 밥상
# 5     서울특별시 송파구 새서울세탁
# 6  서울특별시 송파구 송천엄마손칼국수
# 7     서울특별시 송파구 방이뚝배기
# 8     서울특별시 동남로 새서울세탁
# 9    서울특별시 금천구 먹거리휴게소

# %%
df['검색어'].values
# Out:
# array(['서울특별시 동대문구 신원식당', '서울특별시 은평구 신미가 맛집', '서울특별시 은평구 북한산 손칼국수', ...,
#        '서울특별시 강남구 지리산', '서울특별시 강남구 선경헤어샵', '서울특별시 강남구 청송숯불화로구이'],
#       dtype=object)
